# %%
#imports
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import seaborn as sns
from pandas.plotting import scatter_matrix
from sklearn.datasets import fetch_california_housing
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Part 1
#
# What are the candidate features of this dataset that could be removed according to variance
# thresholding or correlation-based feature selection? Explain how you derive the candidates by
# means of plots or tables and choose at least three features that are candidates for removal.

# %% [markdown]
# find out how to turn whatever the fuck the db is into a data frame
#
# graph all features against price
#
# low then find correlation
#
# idk how to do the variance version

# %%
# get data
data = fetch_california_housing()
print(data['target'])
X = data['data']
y = data['target']
#print(data['DESCR'])
#print(type(data))

df = pd.DataFrame(data.data, columns=data.feature_names)
df['Target'] = data.target
#print(df.head())


#plot all features against target
# Define the y-axis columns for the scatter plots

y_columns = ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# Fit and transform the data using Z-score scaling

df_scaled = df.copy()
scaler = StandardScaler()
df_scaled[y_columns] = scaler.fit_transform(df[y_columns])


# Create the figure and the subplots

fig, axes = plt.subplots(4, 2, figsize=(10, 15))

fig.suptitle('Scatter Plots of Scaled Features vs Target', fontsize=16)



# Plot each scatter plot in the figure

for idx, column in enumerate(y_columns):
    row = idx // 2
    col = idx % 2
    ax = axes[row, col]
    ax.scatter(df_scaled['Target'], df_scaled[column], alpha=0.7)
    ax.set_title(f'Scaled {column} vs Target')
    ax.set_xlabel('Target')
    ax.set_ylabel(f"Scaled {column}")

# Adjust layout

plt.tight_layout(rect=[0, 0, 1, 0.96])

plt.show()
# Out:
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]
# <img src="data:image/png;base64,..." width="1000">

# %%
#Variance threashold time
df_features = pd.DataFrame(data.data, columns=data.feature_names)
df_Target = data.target

min_max_scaler = MinMaxScaler()
df_features_min_max_scaled = df_features.copy()
df_features_min_max_scaled[y_columns] = min_max_scaler.fit_transform(df_features[y_columns])

variances = df_features_min_max_scaled.var()

# Display variances to help decide on the threshold
print(variances)

variances_raw = df.var()
print(variances_raw)
var_thres = VarianceThreshold(threshold=0.00001)
df_features_min_max_scaled.head()
var_thres.fit(df_features_min_max_scaled)
# Out:
# MedInc        0.017166
# HouseAge      0.060898
# AveRooms      0.000308
# AveBedrms     0.000197
# Population    0.001007
# AveOccup      0.000070
# Latitude      0.051523
# Longitude     0.039822
# dtype: float64
# MedInc        3.609323e+00
# HouseAge      1.583963e+02
# AveRooms      6.121533e+00
# AveBedrms     2.245915e-01
# Population    1.282470e+06
# AveOccup      1.078700e+02
# Latitude      4.562293e+00
# Longitude     4.014139e+00
# Target        1.331615e+00
# dtype: float64
# VarianceThreshold(threshold=1e-05)

# %%
#Correlation feature time
df_features = pd.DataFrame(data.data, columns=data.feature_names)
df_Target = data.target

plt.figure(figsize=(12,10))
cor = df_features.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# From variance threashold: idk why but the variance threashold aint working. I can do it manually: min-max scaling the data and using a threashold of 0.0001 We can remove AveOccup.
#
# From using correlation-based feature selection: lattitide/longitude have a correlation of .92, and AveRooms/AveBedrooms have a correlation of .85. Meaning we can quite confidently remove one of each of these pairs. We'll choose to remove the one with lower variance.
#
# Thus the candidates for removal are: AveOccup, Longitude, and AveBedrooms

# %% [markdown]
# # Part 2
#
# Implement a function that returns the regression model for a given design matrix and target
# vector. Fit and evaluate four regression models (with affine basis functions) using (I) all features
# and (II-IV) all but one of the three candidate features from the previous part. Use 5-fold cross-
# validation to evaluate your regression models. Add a table in the report with the cross-validated
# scores for each of your regression models.

# %% [markdown]
# plan:
# find out how to make a design matrix
# and target vector
# in python

# %% [markdown]
# # Part 3
# interpret your results.
# ◦ Would you recommend removing one of the candidate features?
# ◦ What would you infer from the cross-validated scores?
# Justify your analysis and discuss possible benefits and drawbacks when removing one of the
# features vs. keeping all features.

# %% [markdown]
# pros of removeing features: less complexity, easier to do stuff
# cons of removing stuff: aint gonna be perfect
